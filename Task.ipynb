# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://sb1map.dot.ca.gov/SB1MAP/data/All_Projects.csv"

df = pd.read_csv(url)
print(df.head())
# Out:
#         ProjectID                                       ProjectTitle  \
# 0  'LSR-0318-0248         Sierra City Community Streets Maintenance.
# 1   'ATP1-07-160M  City of Lancaster - Safe Routes to School Mast...
# 2   'ATP1-07-161M  Arroyo Simi Greenway Bike Trail Phase 3 (ATP C...
# 3   'ATP1-07-162M  Maine Avenue Corridor Complete Streets Improve...
# 4   'ATP1-07-163M  Proposed Oxnard Boulevard Bike Lanes (ATP Cycl...
#
#                          Program  \
# 0        Local Streets and Roads
# 1  Active Transportation Program
# 2  Active Transportation Program
# 3  Active Transportation Program
# 4  Active Transportation Program
#
#                                   ProjectDescription  TotalCost  SB1Funds  \
# 0  This project will include: Complete necessary ...    25483.0   25483.0
# 1  In the City of Lancaster. The project will pro...   366000.0       0.0
# 2  A 12 mile pedestrian and bike trail that exten...  1330000.0       0.0
# 3  Construct complete streets improvements along ...  3651000.0       0.0
# 4  Install class II bike lanes on both directions...  1372000.0       0.0
#
#      ImplementingAgency AssemblyDistricts SenateDistricts  CountyNames  ...  \
# 0         Sierra County                01              01       Sierra  ...
# 1     City of Lancaster            34, 39              21  Los Angeles  ...
# 2   City of Simi Valley                42              27      Ventura  ...
# 3  City of Baldwin Park                48              22  Los Angeles  ...
# 4        City of Oxnard                38              19      Ventura  ...
#
#   CT_Codes ProjectStatusCodes AgencyID IIJAProgram IIJACodes IIJAFunds IsIIJA  \
# 0     |03|        |Completed|     5913         NaN       NaN       0.0      N
# 1     |07|        |Completed|     5419         NaN       NaN       NaN      N
# 2     |07|        |Completed|     5405         NaN       NaN       NaN      N
# 3     |07|        |Completed|     5323         NaN       NaN       NaN      N
# 4     |07|          |Planned|     5129         NaN       NaN       NaN      N
#
#   IsIIJACode CongressionalDistricts CongressionalCodes
# 0        |N|                     03               |03|
# 1        |N|                     27               |27|
# 2        |N|                     26               |26|
# 3        |N|                     31               |31|
# 4        |N|                     26               |26|
#
# [5 rows x 35 columns]

# %%
import pandas as pd

# Read the city data(data_set)
city_df = pd.read_csv("city_data.csv")

# Check column names of city_df
print(city_df.columns)

# Assuming the correct column name is "County"
merged_df = pd.merge(df, city_df, left_on="CountyNames", right_on="CT_Codes")

print(merged_df)
# Out:
# Index(['ProjectID', 'ProjectTitle', 'Program', 'ProjectDescription',
#        'TotalCost', 'SB1Funds', 'ImplementingAgency', 'AssemblyDistricts',
#        'SenateDistricts', 'CountyNames', 'CityNames', 'CT_Districts',
#        'DateUpdated', 'ProjectStatus', 'ProgramCodes', 'IsOnSHS',
#        'IsOnSHSCode', 'IsSB1', 'IsSB1Code', 'FiscalYear', 'FiscalYearCode',
#        'AssemblyCodes', 'SenateCodes', 'CountyCodes', 'CityCodes', 'CT_Codes',
#        'ProjectStatusCodes', 'AgencyID', 'IIJAProgram', 'IIJACodes',
#        'IIJAFunds', 'IsIIJA', 'IsIIJACode', 'CongressionalDistricts',
#        'CongressionalCodes'],
#       dtype='object')
#       ProjectID_x                                     ProjectTitle_x  \
# 0     '0322000257  Clean Air Transportation Program in Sacramento...
# 1     '0322000257  Clean Air Transportation Program in Sacramento...
# 2     '0322000257  Clean Air Transportation Program in Sacramento...
# 3     '0322000257  Clean Air Transportation Program in Sacramento...
# 4     '0322000257  Clean Air Transportation Program in Sacramento...
# ...           ...                                                ...
# 8699  '0322000305  Project in Sacramento Area Council of Governments
# 8700  '0322000305  Project in Sacramento Area Council of Governments
# 8701  '0322000305  Project in Sacramento Area Council of Governments
# 8702  '0322000305  Project in Sacramento Area Council of Governments
# 8703  '0322000305  Project in Sacramento Area Council of Governments
#
#                      Program_x  \
# 0     Federal Formula Programs
# 1     Federal Formula Programs
# 2     Federal Formula Programs
# 3     Federal Formula Programs
# 4     Federal Formula Programs
# ...                        ...
# 8699  Federal Formula Programs
# 8700  Federal Formula Programs
# 8701  Federal Formula Programs
# 8702  Federal Formula Programs
# 8703  Federal Formula Programs
#
#                                    ProjectDescription_x  TotalCost_x  \
# 0      Clean Air Transportation Program in Sacrament...          NaN
# 1      Clean Air Transportation Program in Sacrament...          NaN
# 2      Clean Air Transportation Program in Sacrament...          NaN
# 3      Clean Air Transportation Program in Sacrament...          NaN
# 4      Clean Air Transportation Program in Sacrament...          NaN
# ...                                                 ...          ...
# 8699   Project in Sacramento Area Council of Governm...          NaN
# 8700   Project in Sacramento Area Council of Governm...          NaN
# 8701   Project in Sacramento Area Council of Governm...          NaN
# 8702   Project in Sacramento Area Council of Governm...          NaN
# 8703   Project in Sacramento Area Council of Governm...          NaN
#
#       SB1Funds_x                               ImplementingAgency_x  \
# 0            0.0  Sacramento Metropolitan Air Quality Management...
# 1            0.0  Sacramento Metropolitan Air Quality Management...
# 2            0.0  Sacramento Metropolitan Air Quality Management...
# 3            0.0  Sacramento Metropolitan Air Quality Management...
# 4            0.0  Sacramento Metropolitan Air Quality Management...
# ...          ...                                                ...
# 8699         0.0             Sacramento Area Council of Governments
# 8700         0.0             Sacramento Area Council of Governments
# 8701         0.0             Sacramento Area Council of Governments
# 8702         0.0             Sacramento Area Council of Governments
# 8703         0.0             Sacramento Area Council of Governments
#
#      AssemblyDistricts_x SenateDistricts_x CountyNames_x  ... CT_Codes_y  \
# 0                    NaN               NaN           NaN  ...        NaN
# 1                    NaN               NaN           NaN  ...        NaN
# 2                    NaN               NaN           NaN  ...        NaN
# 3                    NaN               NaN           NaN  ...        NaN
# 4                    NaN               NaN           NaN  ...        NaN
# ...                  ...               ...           ...  ...        ...
# 8699                  06                08           NaN  ...        NaN
# 8700                  06                08           NaN  ...        NaN
# 8701                  06                08           NaN  ...        NaN
# 8702                  06                08           NaN  ...        NaN
# 8703                  06                08           NaN  ...        NaN
#
#      ProjectStatusCodes_y AgencyID_y  \
# 0                     NaN        NaN
# 1                     NaN        NaN
# 2                     NaN        NaN
# 3                     NaN        NaN
# 4                     NaN        NaN
# ...                   ...        ...
# 8699                  NaN        NaN
# 8700                  NaN        NaN
# 8701                  NaN        NaN
# 8702                  NaN        NaN
# 8703                  NaN        NaN
#
#                                           IIJAProgram_y IIJACodes_y  \
# 0           National Highway Performance Program (NHPP)      |NHPP|
# 1             Highway Safety Improvement Program (HSIP)      |HSIP|
# 2                         Metropolitan Planning Program       |MPP|
# 3                         Metropolitan Planning Program       |MPP|
# 4                         Metropolitan Planning Program       |MPP|
# ...                                                 ...         ...
# 8699  Research, Development, and Technology Transfer...       |RDT|
# 8700  Research, Development, and Technology Transfer...       |RDT|
# 8701   Safe and Accessible Transportation Options - SPR   |SATOSPR|
# 8702                        State Planning and Research       |SPR|
# 8703                        State Planning and Research       |SPR|
#
#       IIJAFunds_y IsIIJA_y IsIIJACode_y CongressionalDistricts_y  \
# 0     247606954.0        Y          |Y|                      NaN
# 1       1890000.0        Y          |Y|                      NaN
# 2      23649647.0        Y          |Y|                      NaN
# 3        771058.0        Y          |Y|                      NaN
# 4       1800949.0        Y          |Y|                      NaN
# ...           ...      ...          ...                      ...
# 8699   17075657.0        Y          |Y|                      NaN
# 8700   16438052.0        Y          |Y|                      NaN
# 8701    2275891.0        Y          |Y|                      NaN
# 8702   62316970.0        Y          |Y|                      NaN
# 8703   62414884.0        Y          |Y|                      NaN
#
#      CongressionalCodes_y
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 8699                  NaN
# 8700                  NaN
# 8701                  NaN
# 8702                  NaN
# 8703                  NaN
#
# [8704 rows x 70 columns]

# %%
df = df[['ProjectID', 'ProjectTitle', 'ProjectDescription', 'TotalCost', 'CountyNames', 'CT_Codes', 'ProjectStatusCodes']]
print(df.head())
# Out:
#         ProjectID                                       ProjectTitle  \
# 0  'LSR-0318-0248         Sierra City Community Streets Maintenance.
# 1   'ATP1-07-160M  City of Lancaster - Safe Routes to School Mast...
# 2   'ATP1-07-161M  Arroyo Simi Greenway Bike Trail Phase 3 (ATP C...
# 3   'ATP1-07-162M  Maine Avenue Corridor Complete Streets Improve...
# 4   'ATP1-07-163M  Proposed Oxnard Boulevard Bike Lanes (ATP Cycl...
#
#                                   ProjectDescription  TotalCost  CountyNames  \
# 0  This project will include: Complete necessary ...    25483.0       Sierra
# 1  In the City of Lancaster. The project will pro...   366000.0  Los Angeles
# 2  A 12 mile pedestrian and bike trail that exten...  1330000.0      Ventura
# 3  Construct complete streets improvements along ...  3651000.0  Los Angeles
# 4  Install class II bike lanes on both directions...  1372000.0      Ventura
#
#   CT_Codes ProjectStatusCodes
# 0     |03|        |Completed|
# 1     |07|        |Completed|
# 2     |07|        |Completed|
# 3     |07|        |Completed|
# 4     |07|          |Planned|

# %%
df_filtered = df[df['CountyNames'].isin(['Bakersfield', 'Richmond'])]

print(df_filtered)
# Out:
# Empty DataFrame
# Columns: [ProjectID, ProjectTitle, ProjectDescription, TotalCost, CountyNames, CT_Codes, ProjectStatusCodes]
# Index: []

# %%
city_url = "https://sb1map.dot.ca.gov/SB1MAP/data/Cities.csv"
city_df = pd.read_csv(city_url)

city_df.head()
# Out:
#            City CityCode          County CountyCode  Lon_Centroid  \
# 0      Adelanto     ADEL  San Bernardino        SBD   -117.441234
# 1  Agoura Hills     AGRH     Los Angeles         LA   -118.760110
# 2       Alameda      ALA         Alameda        ALA   -122.278289
# 3        Albany      ALB         Alameda        ALA   -122.300416
# 4      Alhambra      ALH     Los Angeles         LA   -118.135526
#
#    Lat_Centroid
# 0     34.586868
# 1     34.153635
# 2     37.779933
# 3     37.889852
# 4     34.083981

# %%
merged_df = pd.merge(df, city_df, left_on="CountyNames", right_on="County")

print(merged_df)
# Out:
#              ProjectID                                       ProjectTitle  \
# 0       'LSR-0318-0248         Sierra City Community Streets Maintenance.
# 1       'LSR-0318-0249               Sierra City Lakes Basin Maintenance.
# 2       'LSR-0318-0250       Unimproved County Road Maintenance East Side
# 3       'LSR-0318-0251       Unimproved County Road Maintenance West Side
# 4          '0320000034                              Permanent Restoration
# ...                ...                                                ...
# 350179  'LSR-0222-5407               Southeast Susanville Gateway Project
# 350180  'LSR-0222-5408  Maintenance Activities to be Performed by City...
# 350181  'LSR-0222-5409  HMA Overlay and ADA Curb Ramp Upgrades on loca...
# 350182     '0219000111                Mobility - Operational Improvements
# 350183   'ATP6-02-004S  Riverside Drive Pedestrian and Bike Trail Proj...
#
#                                        ProjectDescription   TotalCost  \
# 0       This project will include: Complete necessary ...    25483.00
# 1       This project will include: Complete necessary ...    39040.00
# 2       This project will include: This project will i...    43956.00
# 3       This project will include: This project will i...    47841.00
# 4       A $1.19 million dollar project in Sierra Count...  1186370.03
# ...                                                   ...         ...
# 350179      This project will include: Preliminary Design    30184.00
# 350180  This project will include: Maintenance Program...   158000.00
# 350181  This project will include: Sidewalk and/or Cro...   120000.00
# 350182  Near Susanville, from 1.3 miles east of Route ...  1548800.00
# 350183  Construct separated Class I bicycle/pedestrian...  3111000.00
#
#        CountyNames CT_Codes ProjectStatusCodes        City CityCode  County  \
# 0           Sierra     |03|        |Completed|    Loyalton      LOY  Sierra
# 1           Sierra     |03|        |Completed|    Loyalton      LOY  Sierra
# 2           Sierra     |03|        |Completed|    Loyalton      LOY  Sierra
# 3           Sierra     |03|        |Completed|    Loyalton      LOY  Sierra
# 4           Sierra     |03|        |Completed|    Loyalton      LOY  Sierra
# ...            ...      ...                ...         ...      ...     ...
# 350179      Lassen     |02|       |InProgress|  Susanville     SUSV  Lassen
# 350180      Lassen     |02|       |InProgress|  Susanville     SUSV  Lassen
# 350181      Lassen     |02|       |InProgress|  Susanville     SUSV  Lassen
# 350182      Lassen     |02|       |InProgress|  Susanville     SUSV  Lassen
# 350183      Lassen     |02|          |Planned|  Susanville     SUSV  Lassen
#
#        CountyCode  Lon_Centroid  Lat_Centroid
# 0             SIE   -120.244824     39.676860
# 1             SIE   -120.244824     39.676860
# 2             SIE   -120.244824     39.676860
# 3             SIE   -120.244824     39.676860
# 4             SIE   -120.244824     39.676860
# ...           ...           ...           ...
# 350179        LAS   -120.657277     40.421154
# 350180        LAS   -120.657277     40.421154
# 350181        LAS   -120.657277     40.421154
# 350182        LAS   -120.657277     40.421154
# 350183        LAS   -120.657277     40.421154
#
# [350184 rows x 13 columns]

# %%
# user_input = input("Enter a city name: ")
city_name = ['Richmond', 'bakersfield', 'wasco', 'eureka', 'Arcata', 'Mckinleyville', 'sanrafael', 'novato', 'Millivalley', 'Riverside', 'moreno', 'Corona', 'sacramento', 'citrus heights', 'elk grove', 'San Bernardino', 'Fontana', 'Ontario', 'Chula Vista', 'OceanSide', 'san', 'paso', 'atascadero', 'sanmateo', 'daily', 'lompoc', 'santa maria', 'santa clara', 'vacaville', 'vallejo', 'fairfield', 'Rohnert', 'santa', 'petaluma', 'thousand', 'simivalley', 'shoreline']

filtered_df = pd.DataFrame()
for name in city_name:

    for index, row in merged_df.iterrows():
        if row["City"] == name:
      # filtered_df = filtered_df.append(row)
          filtered_df = pd.concat([filtered_df, pd.DataFrame(row).T], ignore_index=True)


print(filtered_df)
# Out:
#            ProjectID                                       ProjectTitle  \
# 0     'LSR-0419-0358                  2018 Neighborhood Streets Project
# 1     'LSR-0419-0371          Diamond Boulevard Pavement Rehabilitation
# 2     'LSR-0419-0393                 Sidewalk & Street Sign Maintenance
# 3     'LSR-0419-0394          Street Light & Traffic Signal Maintenance
# 4     'LSR-0419-0395  Street Light, Traffic Signal & Street Sign Rep...
# ...              ...                                                ...
# 4523     '0000201816  Ride Between the Line: Enhancing Access to Tra...
# 4524     '0000201509  San Diego Metropolitan Transit System Trolley ...
# 4525     '0000201817  Blue Line Rail Corridor Transit Enhancements 2...
# 4526     '0000202318             Zero Emission Transit Enhancements 2.0
# 4527     '0000202216  Zero-Emission Transit Enhancement Project 2022:16
#
#                                      ProjectDescription   TotalCost  \
# 0     This project will include: Pavement Rehab/Repa...     64355.0
# 1     This project will include: Paving and/or Strip...     50000.0
# 2     This project will include: Traffic Signals, Li...      3217.0
# 3     This project will include: Traffic Signals, Li...     31800.0
# 4     This project will include: Traffic Signals, Li...     54194.0
# ...                                                 ...         ...
# 4523  Improvements to transit stops for or improved ...  31495000.0
# 4524  Courthouse Trolley Station (Design), Courthous...  43136000.0
# 4525  Increased ridership through investments allowi...  50200000.0
# 4526  The Project will construct a new overhead char...  75559000.0
# 4527  Enhancement project consists of three elements...  41930000.0
#
#        CountyNames CT_Codes ProjectStatusCodes         City CityCode  \
# 0     Contra Costa     |04|        |Completed|     Richmond      RCH
# 1     Contra Costa     |04|        |Completed|     Richmond      RCH
# 2     Contra Costa     |04|        |Completed|     Richmond      RCH
# 3     Contra Costa     |04|        |Completed|     Richmond      RCH
# 4     Contra Costa     |04|        |Completed|     Richmond      RCH
# ...            ...      ...                ...          ...      ...
# 4523     San Diego     |11|          |Planned|  Chula Vista      CHV
# 4524     San Diego     |11|        |Completed|  Chula Vista      CHV
# 4525     San Diego     |11|       |InProgress|  Chula Vista      CHV
# 4526     San Diego     |11|          |Planned|  Chula Vista      CHV
# 4527     San Diego     |11|       |InProgress|  Chula Vista      CHV
#
#             County CountyCode Lon_Centroid Lat_Centroid
# 0     Contra Costa         CC  -122.383056    37.938759
# 1     Contra Costa         CC  -122.383056    37.938759
# 2     Contra Costa         CC  -122.383056    37.938759
# 3     Contra Costa         CC  -122.383056    37.938759
# 4     Contra Costa         CC  -122.383056    37.938759
# ...            ...        ...          ...          ...
# 4523     San Diego         SD  -116.975272    32.628803
# 4524     San Diego         SD  -116.975272    32.628803
# 4525     San Diego         SD  -116.975272    32.628803
# 4526     San Diego         SD  -116.975272    32.628803
# 4527     San Diego         SD  -116.975272    32.628803
#
# [4528 rows x 13 columns]

# %%
filtered_df.to_csv('scraped_data.csv')
